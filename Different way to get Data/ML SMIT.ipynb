# %% [raw]
# Q: Can we predict whether someone has heart disease based on their health measurements?
#
# BINARY CLASSIFICATION Predict one of two possible categories 0 or 1, Yes or No, True or False
#
# MULTI CLASS CLASSIFICATION Predict one of more than two categories Example: What type of animal is this? (Cat, Dog, Horse)
#
# REGRESSION: Predict a continuous numerical value Example: Predict the selling price of a house
#
# MULTI LABEL CLASSIFICATION Predict multiple binary labels for each instance Example: Predict which genres apply to a movie (Action, Comedy, Thriller, Drama etc)
#
# CLUSTERING Group similar items together without labeled targets (Unsupervised Learning) Exaple: Group customers by spending behaviour
#
# ANOMALY DETECTION Find unusual data points that do not fit normal patterns Example: Detecting credit card fraud
#
# TIME SERIES FORECASTING Predict values over time Example: Forecast stock prices / electricity usage over days,weeks,months
#
# Heart Dataset Typpe: Supervised Learning Problem: Binary Classification Goal: Predict Target (1: Disease, 0: No Disease) X: Input: Features : Input data (Age, Thal, Cholesterol, CPType, MaxHR.....) Y: Output: Label : Output Column (Target)
#
# ML Pipeline
#
# Data (dataset) 2.. EDA (shape, missing values, outliers, distribution)
# Cleaning: (Fix datatypes, encode categories)
# Features (Create new features)
# Split (Features (X) and Target(y))
# Model (Use ML algorithms to learn patterns)
# Evaluate (Measure model accuracy, precision, recall, confusion matrix)

# %% [raw]
# Types: Supervised (labeled data) Unsupervised (no labels) Reinforcement (learning through rewards)
#
# Structured / Unstructured Data Structured (Tabular: CSV,SQL Tables) Unstructured (Text, images, videos)
#
# Training Set: Used to train the model Testing Set: Used to evaluate final model performance **Validation Set: (optional) Used for tuning models (hyperparameters)
#
# Basic Probability & Statistics Mean, Median, Mode, Standard Deviation Probability, Conditional Probability Distributions (Normal, Skewed)
#
# Standard Deviation (Spread of data) Measures how far values are from the mean
#
# Low std dev = data tightly packed High std dev = data is spread out
#
# Group A: [150, 151,149, 150, 150] Group B: [100, 200, 150, 180, 120]
#
# Chances of an event occuring is Probability If 20 out of 100 people have heart disease P(disease)= 20 / 100 = 0.20 * 100 = 20%
#
# Conditional Probability Probability of one event given that another event has occured P(disease|Chest Pain = Yes) = Probability that a patient has heart disease given that they reported chest pain
#
# Correlation vs Causation
#
# COrrelation: -1 to +1 0: no correlation Higher cholesterol might be correlated with higher chance of heart disease
#
# Causation: One variable directly causes a change in another
#
# Ex: Smoking causes lung damage
#
# Bias: Error from wrong assumptions
#
# Bias is the error due to overly simplistic assumptions in the learning algorithm Leads to underfitting
#
# Variance is error due to model sensitivity to small fluctuations in the training set High Variance: Model captures noise and fluctuations, not just the undelying problem Leads to overfitting
#
# Underfitting: Happens when your model is too simple to learn the underlying pattern Both training and testing errors are high
#
# Overfitting: Model learns both the signal and the noise from training data training error is very low, but test error is high

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sharmaroshan/Heart-UCI-Dataset/master/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.columns = ['Age', 'Sex', 'ChestPainType' , 'RestBP','Cholesterol', 'FBS', 'RestECG',
              'MaxHR','ExerciseAngina','Oldpeak','ST_Slope','NumVesselsFluoro','Thal','Target']

# %% [markdown]
# # one hotencoding

# %%
df_encoded = pd.get_dummies(df,columns=['ChestPainType','Thal'],drop_first=True)
df_encoded.head()
# Out:
#    Age  Sex  RestBP  Cholesterol  FBS  RestECG  MaxHR  ExerciseAngina  \
# 0   63    1     145          233    1        0    150               0
# 1   37    1     130          250    0        1    187               0
# 2   41    0     130          204    0        0    172               0
# 3   56    1     120          236    0        1    178               0
# 4   57    0     120          354    0        1    163               1
#
#    Oldpeak  ST_Slope  NumVesselsFluoro  Target  ChestPainType_1  \
# 0      2.3         0                 0       1            False
# 1      3.5         0                 0       1            False
# 2      1.4         2                 0       1             True
# 3      0.8         2                 0       1             True
# 4      0.6         2                 0       1            False
#
#    ChestPainType_2  ChestPainType_3  Thal_1  Thal_2  Thal_3
# 0            False             True    True   False   False
# ...
